# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key = "AIzaSyAZ9UCSvu9N1u2Pt9UygfsW51cFLPkfYQw"
video_id = "jMR0PUZCHhI"

youtube = build('youtube', 'v3', developerKey=api_key)

def get_comments_for_video(youtube, video_id):
    """Retrieves comments for a given video ID."""
    all_comments = []
    next_page_token = None

    while True:
        comment_request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            pageToken=next_page_token,
            textFormat="plainText",
            maxResults=100
        )
        comment_response = comment_request.execute()

        for item in comment_response['items']:
            top_comment = item['snippet']['topLevelComment']['snippet']
            like_count = top_comment.get('likeCount', 0)
            all_comments.append({
                'Timestamp': top_comment['publishedAt'],
                'Username': top_comment['authorDisplayName'],
                'VideoID': video_id,
                'Comment': top_comment['textDisplay'],
                'Likes': like_count,
                'Date': top_comment['updatedAt'] if 'updatedAt' in top_comment else top_comment['publishedAt']\
            })

        next_page_token = comment_response.get('nextPageToken')
        if not next_page_token:
            break

    return all_comments

all_comments = get_comments_for_video(youtube, video_id)

dfs = pd.DataFrame(all_comments)
dfs
# Out:
#                  Timestamp            Username      VideoID  \
# 0     2024-06-22T02:34:33Z      @meeyamoto2479  jMR0PUZCHhI
# 1     2024-05-20T15:34:01Z       @EzeRas-fj7og  jMR0PUZCHhI
# 2     2024-04-20T21:47:18Z          @Spikspeak  jMR0PUZCHhI
# 3     2024-03-20T15:09:07Z         @virgo.2708  jMR0PUZCHhI
# 4     2024-02-28T08:36:52Z           @Kabut_29  jMR0PUZCHhI
# ...                    ...                 ...          ...
# 7578  2019-05-14T13:33:11Z  @dimasprasetya2595  jMR0PUZCHhI
# 7579  2019-05-14T13:32:57Z          @iopiop403  jMR0PUZCHhI
# 7580  2019-05-14T13:32:09Z        @fuckboy4206  jMR0PUZCHhI
# 7581  2019-05-14T13:31:58Z   @kenzokomando6709  jMR0PUZCHhI
# 7582  2019-05-14T13:31:43Z            @nouka72  jMR0PUZCHhI
#
#                                                 Comment  Likes  \
# 0     Oh ini orasi yang menyulut banyak korban demo ...      0
# 1                                              Login bg      0
# ...

# %%
dfs = dfs.sort_values(by='Likes', ascending=False)
dfs[['Username','Comment','Likes']]
# Out:
#                      Username  \
# 6436            @rossonerri84
# 5831       @goodpeoplethebest
# 7507          @helmiogood3019
# 5776                @Bb-wv9tz
# 6322  @sukarno2tambahmulyo750
# ...                       ...
# 1262           @umierlina2279
# 1260        @hendrimansah9073
# 1257            @dannytan8534
# 12           @Yogatigabelas13
# 23          @kolektorkadrun88
#
#                                                 Comment  Likes
# 6436  Yang percaya sama KPU, mana jempolny????👍\nYan...   1863
# 5831  Testing Survei aja\nRakyat mendukung 01 tekan ...   1037
# 7507  Ayo dukung Jokowi 2 priode !! \n\nyang menolak...   1000
# 5776  sapa yg liat vidio ini smbil bersungut2 jengke...    784
# 6322  Kalau kamu menolak kerja KPU mengapa calekmu y...    763
# ...                                                 ...    ...
# 1262                            jangan bw bw rakyat pa.      0
# 1260  KPU karna ketauan jahat nya curang tak perlu d...      0
# ...

# %%
csv_file = 'df_yt1_2019.csv'
dfs.to_csv(csv_file, index=False)

from google.colab import files

files.download(csv_file)

# %%
csv_file = 'df_yt3_2019.csv'
dfs.to_csv(csv_file, index=False)

# %% [markdown]
# ## import

# %%
#import data
import pandas as pd
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/pemiluYT3.csv'
df = pd.read_csv(file_path)

df
# Out:
# Mounted at /content/drive
#                   Timestamp               Username      VideoID  \
# 0      2025-03-09T07:12:10Z    @sugengsutardjo7258  0hDV7S1WTWA
# 1      2025-03-06T23:05:04Z     @frizzysumaila6395  0hDV7S1WTWA
# 2      2025-01-21T06:01:02Z              @miikeadr  0hDV7S1WTWA
# 3      2025-01-04T02:43:32Z             @KeomiSaja  0hDV7S1WTWA
# 4      2024-11-16T13:04:31Z      @SeptiyanaDwi-x7k  0hDV7S1WTWA
# ...                     ...                    ...          ...
# 43928  2023-12-22T17:22:15Z     @sherennirmala1127  J1WUpRCzK44
# 43929  2023-12-22T17:16:03Z           @sexymia3942  J1WUpRCzK44
# 43930  2023-12-22T17:09:45Z       @sudipracaya4279  J1WUpRCzK44
# 43931  2023-12-22T16:59:01Z  @titiponnpratchai2702  J1WUpRCzK44
# 43932  2023-12-22T16:57:58Z  @bintangalmuhafiz9090  J1WUpRCzK44
#
#                                                  Comment  Likes  \
# 0      YA IA IMAN PERCAYA ADU DEBAT YANG BISA MENJADI...      0
# ...
